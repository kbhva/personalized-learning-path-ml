# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
# %matplotlib inline

# %%
df = pd.read_csv("../datasets/resources.csv")
df.head()
# Out:
#       video_id                                              title  \
# 0  3LaVxEX3F0o  Computer Vision and Image Processing – Fundame...
# 1  0qPG8wCRBbo  TensorFlow en Solo 60 Segundos! 🚀 #tensorflow ...
# 2  bn72j7RiBv8      🚨🚨 Rebuilding PyTorch in Rust: Fast | Safe 🚨🚨
# 3  BFlRmIvqwSA               Top 25 Computer Vision Projects 2021
# 4  13NQ3IWKL5I  Data Analyst कैसे बने? | Fastest Roadmap to Le...
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=3LaVxEX3F0o
# 1  https://www.youtube.com/watch?v=0qPG8wCRBbo
# 2  https://www.youtube.com/watch?v=bn72j7RiBv8
# 3  https://www.youtube.com/watch?v=BFlRmIvqwSA
# 4  https://www.youtube.com/watch?v=13NQ3IWKL5I
#
#                                          description          publish_date  \
# 0  Computer Vision and Image Processing – Fundame...  2020-11-24T10:23:57Z
# 1  TensorFlow en Solo 60 Segundos! 🚀 #tensorflow ...  2024-10-22T17:54:02Z
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9805 entries, 0 to 9804
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       9279 non-null   object
#  1   title          9805 non-null   object
#  2   url            9805 non-null   object
#  3   description    8468 non-null   object
#  4   publish_date   9279 non-null   object
#  5   channel_title  9279 non-null   object
#  6   view_count     9279 non-null   float64
#  7   duration       9274 non-null   object
#  8   tags           6201 non-null   object
#  9   topic          9805 non-null   object
#  10  length         526 non-null    float64
#  11  popularity     526 non-null    float64
#  12  rating         526 non-null    float64
#  13  difficulty     526 non-null    object
#  14  type           526 non-null    object
# dtypes: float64(4), object(11)
# memory usage: 1.1+ MB
# video_id          526
# title               0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y="topic", data=df, order=df['topic'].value_counts().index)
plt.title("Number of Resources per Topic")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="length", y="popularity", hue="difficulty", data=df)
plt.title("Length vs Popularity colored by Difficulty")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["rating"], bins=20, kde=True)
plt.title("Rating Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="difficulty", data=df)
plt.title("Difficulty Distribution")
plt.show()
